# %% [markdown]
# <a href="https://colab.research.google.com/github/kasireddyasam/AI-course-/blob/main/FIFA_ipynb_Project_with_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_csv('players_fifa23.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18539 entries, 0 to 18538
# Data columns (total 90 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 18539 non-null  int64
#  1   Name               18539 non-null  object
#  2   FullName           18539 non-null  object
#  3   Age                18539 non-null  int64
#  4   Height             18539 non-null  int64
#  5   Weight             18539 non-null  int64
#  6   PhotoUrl           18539 non-null  object
#  7   Nationality        18539 non-null  object
#  8   Overall            18539 non-null  int64
#  9   Potential          18539 non-null  int64
#  10  Growth             18539 non-null  int64
#  11  TotalStats         18539 non-null  int64
#  12  BaseStats          18539 non-null  int64
#  13  Positions          18539 non-null  object
#  14  BestPosition       18539 non-null  object
#  15  Club               18539 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# ID           0
# Name         0
# FullName     0
# Age          0
# Height       0
#             ..
# RWBRating    0
# LBRating     0
# CBRating     0
# RBRating     0
# GKRating     0
# Length: 90, dtype: int64

# %% [markdown]
# Taking impo colimns

# %%
needed_cols=['ID', 'Name', 'FullName', 'Age', 'Height', 'Weight' ,
        'Overall', 'Potential', 'Growth', 'TotalStats',
       'BaseStats', 'BestPosition', 'Club', 'ValueEUR', 'WageEUR',
       'ReleaseClause', 'ContractUntil',
       'ClubJoined', 'OnLoad',  'PreferredFoot', 'IntReputation', 'WeakFoot','Nationality',
       'SkillMoves', 'AttackingWorkRate', 'DefensiveWorkRate', 'PaceTotal',
       'ShootingTotal', 'PassingTotal', 'DribblingTotal', 'DefendingTotal',
       'PhysicalityTotal', 'Crossing', 'Finishing', 'HeadingAccuracy',
       'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
       'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
       'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
       'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
       'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle',
       'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes']

# %% [markdown]
# Checking for the null values and deleting becous it % is very low

# %%
  df = df[needed_cols]

# %%
for i in df.columns:
    if df[i].isnull().sum()>1:
      print(i,df[i].isnull().sum())
# Out:
# ContractUntil 92

# %%
df.drop(df[df['ContractUntil'].isnull()].index,inplace=True)

# %% [markdown]
# # 2)Handling Categorical colums

# %%
for i in df.columns:
    if df[i].dtype=='object':
      print(i)
# Out:
# Name
# FullName
# BestPosition
# Club
# PreferredFoot
# Nationality
# AttackingWorkRate
# DefensiveWorkRate

# %%
df['BestPosition'] ## categorie we can do it;
df['BestPosition'].unique()
# here we have 14  position we can group the position and reduce no of diffrent groups
# Out:
# array([ 0,  3, 14,  4, 12,  5,  1,  8,  2,  7,  6, 11, 10,  9, 13])

# %%
df['PreferredFoot'] # left otr right cagtegorie
# Out:
# 0         Left
# 1        Right
# 2        Right
# 3        Right
# 4        Right
#          ...
# 18534    Right
# 18535    Right
# 18536    Right
# 18537    Right
# 18538     Left
# Name: PreferredFoot, Length: 18447, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['PreferredFoot']= le.fit_transform(df['PreferredFoot'])
df['PreferredFoot']
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 18534    1
# 18535    1
# 18536    1
# 18537    1
# 18538    0
# Name: PreferredFoot, Length: 18447, dtype: int64

# %%
df['BestPosition']=le.fit_transform(df['BestPosition'])
x=df['BestPosition']
print(x,x.max())
# Out:
# 0         0
# 1         3
# 2        14
# 3         4
# 4        14
#          ..
# 18534     0
# 18535     2
# 18536    11
# 18537     1
# 18538     6
# Name: BestPosition, Length: 18447, dtype: int64 14

# %%
df['AttackingWorkRate'] = le.fit_transform(df['AttackingWorkRate'])
df['AttackingWorkRate']
# Out:
# 0        1
# 1        2
# 2        0
# 3        0
# 4        0
#         ..
# 18534    2
# 18535    2
# 18536    0
# 18537    2
# 18538    2
# Name: AttackingWorkRate, Length: 18447, dtype: int64

# %%
df['DefensiveWorkRate']
# Out:
# 0           Low
# 1        Medium
# 2        Medium
# 3          High
# 4           Low
#           ...
# 18534    Medium
# 18535    Medium
# 18536    Medium
# 18537    Medium
# 18538    Medium
# Name: DefensiveWorkRate, Length: 18447, dtype: object

# %%
df['DefensiveWorkRate'] = le.fit_transform(df['DefensiveWorkRate'])
df['DefensiveWorkRate']
# Out:
# 0        1
# 1        2
# 2        2
# 3        0
# 4        1
#         ..
# 18534    2
# 18535    2
# 18536    2
# 18537    2
# 18538    2
# Name: DefensiveWorkRate, Length: 18447, dtype: int64

# %%
df['Club'] = le.fit_transform(df['Club'])
x=df['Club']
print(x,x.max())
# Out:
# 0        453
# 1        494
# 2        230
# 3        399
# 4        453
#         ...
# 18534    570
# 18535    312
# 18536    201
# 18537    201
# 18538    431
# Name: Club, Length: 18447, dtype: int64 677

# %%
 df
# Out:
#            ID            Name            FullName  Age  Height  Weight  \
# 0      158023        L. Messi        Lionel Messi   35     169      67
# 1      165153      K. Benzema       Karim Benzema   34     185      81
# 2      188545  R. Lewandowski  Robert Lewandowski   33     185      81
# 3      192985    K. De Bruyne     Kevin De Bruyne   31     181      70
# 4      231747       K. Mbappé       Kylian Mbappé   23     182      73
# ...       ...             ...                 ...  ...     ...     ...
# 18534  243725      D. Collins      Darren Collins   21     174      68
# 18535  261933    Yang Dejiang        Dejiang Yang   17     175      60
# 18536  267823       L. Mullan         Liam Mullan   18     170      65
# 18537  267824    D. McCallion    Daithí McCallion   17     178      65
# 18538  261424        N. Rabha         Nabin Rabha   25     176      66
#
#        Overall  Potential  Growth  TotalStats  ...  Penalties  Composure  \
# ...

# %%
df.to_csv('fifa23_cleaned.csv',index=False)

# %%
df_cleaned= pd.read_csv('fifa23_cleaned.csv')
df_cleaned.head()
# Out:
#        ID            Name            FullName  Age  Height  Weight  Overall  \
# 0  158023        L. Messi        Lionel Messi   35     169      67       91
# 1  165153      K. Benzema       Karim Benzema   34     185      81       91
# 2  188545  R. Lewandowski  Robert Lewandowski   33     185      81       91
# 3  192985    K. De Bruyne     Kevin De Bruyne   31     181      70       91
# 4  231747       K. Mbappé       Kylian Mbappé   23     182      73       91
#
#    Potential  Growth  TotalStats  ...  Penalties  Composure  Marking  \
# 0         91       0        2190  ...         75         96       20
# 1         91       0        2147  ...         84         90       43
# 2         91       0        2205  ...         90         88       35
# 3         91       0        2303  ...         83         89       68
# 4         95       4        2177  ...         80         88       26
#
#    StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# ...

# %%
df.cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18447 entries, 0 to 18446
# Data columns (total 66 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 18447 non-null  int64
#  1   Name               18447 non-null  object
#  2   FullName           18447 non-null  object
#  3   Age                18447 non-null  int64
#  4   Height             18447 non-null  int64
#  5   Weight             18447 non-null  int64
#  6   Overall            18447 non-null  int64
#  7   Potential          18447 non-null  int64
#  8   Growth             18447 non-null  int64
#  9   TotalStats         18447 non-null  int64
#  10  BaseStats          18447 non-null  int64
#  11  BestPosition       18447 non-null  int64
#  12  Club               18447 non-null  int64
#  13  ValueEUR           18447 non-null  int64
#  14  WageEUR            18447 non-null  int64
#  15  ReleaseClause      18447 non-null  int64
# ...
